# %% [markdown]
# Simple ATM Calculator

# %%
balance = float(input("Enter your account balance: "))
withdrawal = float(input("Enter the amount you want to withraw: "))
if balance > withdrawal:
  balance = balance - withdrawal
  print("Your new balance after withdrawal is", balance)
else:
  print("Insufficient balance to withdraw")
# Out:
# Enter your account balance: 2000
# Enter the amount you want to withraw: 1500
# Your new balance after withdrawal is 500.0

# %% [markdown]
# Electricity Bill Generator

# %%
Consumption = float(input("Enter total units consumed: "))
Billamount = 0
if Consumption <= 100:
  Billamount = Consumption*5
  print("Your Bill amount is:", Billamount)
elif Consumption > 100 and Consumption <=200:
  Billamount= 100*5+ (Consumption-100)*7
  print("Your Bill amount is:", Billamount)
else:
  Billamount= 100*5+ 100*7 + (Consumption-200)*10
  print("Your Bill amount is:", Billamount)
# Out:
# Enter total units consumed: 200
# Your Bill amount is: 1200.0

# %% [markdown]
# Temperature Converter

# %%
Tempin = float(input("Enter the temperature: "))
Unit = str(input("Enter C or F: "))
Value = 0
if Unit == "C":
  Value = (Tempin * 9/5) + 32
  print("Value in Farenheit is:", Value)
elif Unit == "F":
  Value = (Tempin - 32) * 5/9
  print("Value in Farenheit is:", Value)
# Out:
# Enter the temperature: 20
# Enter C or F: F
# Value in Farenheit is: -6.666666666666667

# %% [markdown]
# Mobile Recharge Validity

# %%
DOR = float(input("Enter the date of recharge (1-31): "))
if DOR>31:
  print("Pls enter valid date")
  DOR = float(input("Enter the date of recharge (1-31): "))
  TODAY = float(input("Enter today's date (1-31): "))
  if TODAY - DOR < 28:
    print("Plan valid")
  else:
    print("Plan expired")
else:
  TODAY = float(input("Enter today's date (1-31): "))
  if TODAY - DOR < 28:
    print("Plan valid")
  else:
    print("Plan expired")
# Out:
# Enter the date of recharge (1-31): 21
# Enter today's date (1-31): 4
# Plan valid

# %% [markdown]
# Bus Seat Reservation System

# %%
#Take initial bookings
n = int(input("How many passengers booked initially? "))
booked = []

for i in range(n):
    name = input(f"Enter name {i+1}: ")
    booked.append(name)

# Cancellation
cancel = input("Enter the name to cancel: ")
if cancel in booked:
    booked.remove(cancel)
else:
    print("Name not found in the list.")

# New booking
new = input("Enter the new passenger name: ")
position = int(input("Enter the position to insert (0 for first): "))
booked.insert(position, new)

# Show updated list
print("Updated booking list:", booked)
# Out:
# How many passengers booked initially? 2
# Enter name 1: sara
# Enter name 2: neha
# Enter the name to cancel: neha
# Enter the new passenger name: john'
# Enter the position to insert (0 for first): 1
# Updated booking list: ['sara', "john'"]

# %% [markdown]
# Sum of even numberss

# %%
n = int(input("Enter the number to be considered from 1 to:  "))
total=0
for i in range(n):
  if i%2 == 0:
    total = total+i
print("Sum is", total)
# Out:
# Enter the number to be considered from 1 to:  20
# Sum is 90

# %% [markdown]
# Dictionary – Student Marks Summary

# %%
import builtins  # ensures we use the real sum() and len()

# Create an empty dictionary
students = {}

# Take input for 3 students
for i in range(3):
    name = input("Enter name: ")
    marks = float(input("Enter marks: "))
    students[name] = marks

# Calculate average marks using builtins to avoid shadowing issues
average = builtins.sum(students.values()) / builtins.len(students)

# Display result
print("Average Marks:", average)
# Out:
# Enter name: neha
# Enter marks: 50
# Enter name: sneha
# Enter marks: 20
# Enter name: vinu
# Enter marks: 80
# Average Marks: 50.0

# %% [markdown]
# Dictionary – Word Frequency2

# %%
# Take sentence input
sentence = input("Enter the input sentence: ")

# Split sentence into words
words = sentence.split()

# Create an empty dictionary for word frequency
freq = {}

# Count each word
for word in words:
    if word in freq:
        freq[word] += 1
    else:
        freq[word] = 1

# Display the frequency
for word, count in freq.items():
    print(f"{word}: {count}")
# Out:
# Enter the input sentence: I HAVE A PET PET CAT
# I: 1
# HAVE: 1
# A: 1
# PET: 2
# CAT: 1

# %% [markdown]
# Functions – Check Prime

# %%
# Function to check if a number is prime
def is_prime(num):
    if num <= 1:  # Numbers less than or equal to 1 are not prime
        return False
    for i in range(2, num):  # Check divisibility from 2 to num-1
        if num % i == 0:     # If divisible, it's not prime
            return False
    return True  # If no divisors found, it's prime

# Take user input
number = int(input("Enter a number: "))

# Call the function and display result
if is_prime(number):
    print(f"{number} is a prime number.")
else:
    print(f"{number} is not a prime number.")
# Out:
# Enter a number: 24
# 24 is not a prime number.

# %% [markdown]
# Vowel Counter

# %%
def count_vowels(text):
  count = 0
  vowels = "aeiouAEIOU"
  for char in text:
    if char in vowels:
      count = count + 1
  return count


sentence = str(input("Enter the input sentence: "))

print("Number of vowels is:", count_vowels(sentence))
# Out:
# Enter the input sentence: i have a pet cat
# Number of vowels is: 6

# %% [markdown]
# Count Divisible Numbers

# %%
limit = int(input(" Enter the limit range: "))
divisor = int(input("Enter the divisor: "))
count = 0

for i in range(limit):
  if i%divisor == 0:
    count = count + 1

print("Count of numbers divisible by", divisor, ":", count)
# Out:
#  Enter the limit range: 20
# Enter the divisor: 5
# Count of numbers divisible by 5 : 4
